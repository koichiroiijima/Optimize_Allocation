# %%
import pandas as pd
import pandas_datareader as web
import datetime

# %%
aapl = web.DataReader(name='AAPL', 
    data_source='yahoo', 
    start='2021-01-01',
    end=datetime.date.today()
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 aapl = web.DataReader(name='AAPL',
#       2     data_source='yahoo',
#       3     start='2021-01-01',
#       4     end=datetime.date.today()
#       5 )
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas_datareader/data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
#     376         retry_count=retry_count,
#     377         pause=pause,
#     378         session=session,
# --> 379     ).read()
#     381 elif data_source == "iex":
#     382     return IEXDailyReader(
#     383         symbols=name,
#     384         start=start,
#    (...)
#     390         session=session,
#     391     ).read()
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# File ~/.pyenv/versions/3.10.1/lib/python3.10/site-packages/pandas_datareader/yahoo/daily.py:153, in YahooDailyReader._read_one_data(self, url, params)
#     151 try:
#     152     j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153     data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154 except KeyError:
#     155     msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %%
aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   99116600.0
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# ...                ...         ...         ...         ...          ...
# 2022-01-10  172.500000  168.169998  169.080002  172.190002  106606900.0
# 2022-01-11  175.179993  170.820007  172.320007  175.080002   76138300.0
# 2022-01-12  177.179993  174.820007  176.119995  175.529999   74805200.0
# 2022-01-13  176.619995  171.789993  175.779999  172.190002   84505800.0
# 2022-01-14  173.779999  171.089996  171.339996  173.070007   80355000.0
#
#              Adj Close
# Date
# 2020-12-31  131.877014
# 2021-01-04  128.617111
# 2021-01-05  130.207291
# 2021-01-06  125.824326
# 2021-01-07  130.117844
# ...                ...
# 2022-01-10  172.190002
# 2022-01-11  175.080002
# 2022-01-12  175.529999
# 2022-01-13  172.190002
# 2022-01-14  173.070007
#
# [263 rows x 6 columns]

# %%
import pandas as pd
import yfinance as yf
import datetime

# %%
aapl2 = yf.download(tickers='AAPL', 
    start='2021-01-01', 
    end=datetime.date.today(),
    auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl2
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2020-12-31  133.258497  133.914457  130.912956  131.877014   99116600
# 2021-01-04  132.701930  132.791375  125.983346  128.617111  143301900
# 2021-01-05  128.100300  130.932844  127.643112  130.207306   97664900
# 2021-01-06  126.937458  130.247057  125.605665  125.824318  155088000
# 2021-01-07  127.573546  130.823515  127.076610  130.117859  109578200
# ...                ...         ...         ...         ...        ...
# 2022-01-10  169.080002  172.500000  168.169998  172.190002  106606900
# 2022-01-11  172.320007  175.179993  170.820007  175.080002   76138300
# 2022-01-12  176.119995  177.179993  174.820007  175.529999   74805200
# 2022-01-13  175.779999  176.619995  171.789993  172.190002   84505800
# 2022-01-14  171.339996  173.779999  171.089996  173.070007   80355000
#
# [263 rows x 5 columns]

# %%
import sys
from yahoo_finance_api2 import share
from yahoo_finance_api2.exceptions import YahooFinanceError
import pandas as pd

# %%
my_share = share.Share('AAPL')
symbol_data = None

# %%
try:
    symbol_data = my_share.get_historical(
        share.PERIOD_TYPE_DAY, 100,
        share.FREQUENCY_TYPE_DAY, 1
    )
    aapl3 = pd.DataFrame(symbol_data)
    aapl3["Date"] = pd.to_datetime(aapl3.timestamp, unit="ms")
except YahooFinanceError as e:
    print(e.message)
    sys.exit(1)

# %%
aapl3
# Out:
#         timestamp        open        high         low       close     volume  \
# 0   1637159400000  151.000000  155.000000  150.990005  153.490005   88807000
# 1   1637245800000  153.710007  158.669998  153.050003  157.869995  137827700
# 2   1637332200000  157.649994  161.020004  156.529999  160.550003  117305600
# 3   1637591400000  161.679993  165.699997  161.000000  161.020004  117467900
# 4   1637677800000  161.119995  161.800003  159.059998  161.410004   96041900
# 5   1637764200000  160.750000  162.139999  159.639999  161.940002   69463600
# 6   1637937000000  159.570007  160.449997  156.360001  156.809998   76959800
# 7   1638196200000  159.369995  161.190002  158.789993  160.240005   88748200
# 8   1638282600000  159.990005  165.520004  159.919998  165.300003  174048100
# 9   1638369000000  167.479996  170.300003  164.529999  164.770004  152052500
# 10  1638455400000  158.740005  164.199997  157.800003  163.759995  136739200
# 11  1638541800000  164.020004  164.960007  159.720001  161.839996  117938300
# 12  1638801000000  164.289993  167.880005  164.279999  165.320007  107497000
# 13  1638887400000  169.080002  171.580002  168.339996  171.179993  120405400
# 14  1638973800000  172.130005  175.960007  170.699997  175.080002  116998900
# 15  1639060200000  174.910004  176.750000  173.919998  174.559998  108923700
# 16  1639146600000  175.210007  179.630005  174.690002  179.449997  115228100
# 17  1639405800000  181.119995  182.130005  175.529999  175.740005  153237000
# 18  1639492200000  175.250000  177.740005  172.210007  174.330002  139380400
# 19  1639578600000  175.110001  179.500000  172.309998  179.300003  131063300
# 20  1639665000000  179.279999  181.139999  170.750000  172.259995  150185800
